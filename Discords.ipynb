# %% [markdown]
# This example may originally be found here:
#
# https://matrixprofile.org/posts/nyc-taxi-analysis-anomalies-python/

# %%
import matrixprofile as mp
from matrixprofile.visualize import plot_discords_mp
from matplotlib import pyplot as plt
import matplotlib

# %matplotlib inline

# %%
matplotlib.rcParams['figure.figsize'] = (15.0, 10.0)

# %%
dataset = mp.datasets.load('nyc-taxi-anomalies.csv')

# %%
timeseries = dataset['data']

# %%
window_size = 48
profile = mp.compute(dataset['data'], windows=window_size)

# %%
profile = mp.discover.discords(profile, exclusion_zone=window_size, k=5)

# %%
plot_discords_mp(profile)
plt.show()
# Out:
# /home/tyler/anaconda3/envs/pydata2020-mpf/lib/python3.8/site-packages/matrixprofile/visualize.py:375: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
